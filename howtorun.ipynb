# %% [markdown]
# # How to Run a planet simulastion using Hsimulator

# %% [markdown]
# ## Import necessary modules

# %%
import numpy as np
import Hsimulator as H

# %matplotlib inline

# %% [markdown]
# ## Create initial orbit

# %%
# position
x0 = np.array([1.,0,0])
# velocity
v0 = np.array([0,0.75,0])
# orbit
o = [H.orbit(x0,v0)]

# %% [markdown]
# ### Create snapshot

# %%
# initial time
t0 = 0.
# snapshot
snp = H.snapshot(t0,o)

# %% [markdown]
# ### Run the simulation

# %%
H.run(snap=snp, savefile='orbitfile.pkl')
# Out:
#
# *******************************************************************
# *                      PLANET SIMULATION
# *******************************************************************
# * Author    : Hasanuddin
# * copyright : 2021
# * version   : 1.0.0
# *******************************************************************
#
# Potential set for pointmass with G =  1  & M =  1
#
# Integrator set for  leapfrog  with step size =  0.01
#
# Reading snapshot ...
#   1  orbit(s) found
#
# Simulation in progress ...
# ...

# %% [markdown]
# ### Plot relative Energy Error

# %%
H.plot_energy_time('orbitfile.pkl')

# %% [markdown]
# ### Plot Phase Space

# %%
H.plot_phase_space('orbitfile.pkl')
